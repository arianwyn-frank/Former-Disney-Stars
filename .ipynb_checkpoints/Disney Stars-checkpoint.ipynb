# %% [markdown]
# **Disney Channel Stars**
#
# Here is a project where I look at how former Disney Channel Stars are doing now in terms of explicitness of music and populatiry.

# %%
# import your emotional support pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read in data (handcrafted by yours truly)
data = pd.read_csv('disneystars.csv')

# %%
# playground
data.head()
# Out:
#         Artist         Album  Year         Song  Billboard Peak
# 0  Demi Lovato  Don't Forget  2008   La La Land            52.0  \
# 1  Demi Lovato  Don't Forget  2008     Get Back            43.0
# 2  Demi Lovato  Don't Forget  2008   Trainwreck             NaN
# 3  Demi Lovato  Don't Forget  2008        Party             NaN
# 4  Demi Lovato  Don't Forget  2008  On the Line           100.0
#
#    Weeks on Hot 100 Spotify Explicit Tag?
# 0               8.0                   NaN
# 1               6.0                   NaN
# 2               NaN                   NaN
# 3               NaN                   NaN
# 4               1.0                   NaN

# %% [markdown]
# **Demi Lovato**
#
# The first thing that we will do is analyze Demi Lovato's popularity across their albums. This will include explicit metrics as well.

# %%
demi_lovato_df = data[data['Artist'] == 'Demi Lovato']

# Convert the 'Billboard Peak' column to numeric (removing NaN values)
demi_lovato_df.loc[:, 'Billboard Peak'] = pd.to_numeric(demi_lovato_df['Billboard Peak'], errors='coerce')

# Sort the DataFrame by 'Year'
demi_lovato_df = demi_lovato_df.sort_values(by='Year')

# Plotting the Billboard ranking over time as a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(demi_lovato_df['Year'], demi_lovato_df['Billboard Peak'], color='b', label='Billboard Ranking')
plt.title("Demi Lovato's Billboard Ranking Over Time (Scatter Plot)")
plt.xlabel('Year')
plt.ylabel('Billboard Peak')
plt.legend()
plt.grid(True)
plt.show()

# %%
all_albums_df = pd.DataFrame({'Album': demi_lovato_df['Album'].unique()})

# Merge the DataFrame with explicit songs and the DataFrame with all albums
merged_df = pd.merge(all_albums_df, demi_lovato_df, on='Album', how='left')

# Filter rows where the 'Spotify Explicit Tag?' column is 'E' (explicit songs)
explicit_songs_df = merged_df[merged_df['Spotify Explicit Tag?'] == 'E']

# Group by 'Album' and count the number of explicit songs in each album
explicit_songs_counts = explicit_songs_df.groupby('Album')['Spotify Explicit Tag?'].count()

# Plotting the number of explicit songs per Demi Lovato album as a bar chart
plt.figure(figsize=(10, 6))
plt.bar(explicit_songs_counts.index, explicit_songs_counts, color='r', label='Explicit Songs')
plt.title("Number of Explicit Songs per Demi Lovato Album")
plt.xlabel('Album')
plt.ylabel('Number of Explicit Songs')
plt.xticks(rotation=45, ha='right', labels = 'Dont Forget', 'Here we go Again', 'Unbroken')
plt.legend()
plt.show()
# Out:
#   File "C:\TEMP\ipykernel_34764\133514545.py", line 18
#     plt.xticks(rotation=45, ha='right', labels = 'Dont Forget', 'Here we go Again', 'Unbroken')
#                                                                                               ^
# SyntaxError: positional argument follows keyword argument
